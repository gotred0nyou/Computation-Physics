# %%
#Program to create Figure 2.7 from Giordano#

from math import cos,sin,exp,sqrt,pi,radians
from matplotlib import pyplot as plt
xlist=[] #list of data from calculations#
ylist=[] #list of data from calculations#
xheadlist=[]
yheadlist=[]
xtaillist=[]
ytaillist=[]

#variables#
x = 0
y = 1
xhead = 0
yhead = 1
xtail = 0
ytail = 1
v = 49 #initial velocity#
vy = v*sin(radians(35)) #initial velocity in y direction#
vx = v*cos(radians(35)) #initial velocity in x direction#
Vd = 35
delta = 5
g = 9.8 #gravity#
dt = 0.01 #time step#

xlist.append(x)
ylist.append(y)
xheadlist.append(xhead)
yheadlist.append(yhead)
xtaillist.append(xtail)
ytaillist.append(ytail)

def	getNewV (Vx, Vy, Vwind, xy):
    if xy == 0:
        WindDif = Vx-Vwind
        V = Vx
    else:
        WindDif = Vy
        V = Vy
        V -= (g*dt)
    Vadj = sqrt((Vx - Vwind)**2+Vy**2)
    V -= windDrag(Vadj, WindDif)*(0.0039 + (0.0058/(1 + exp((Vadj - Vd)/delta))))*dt
    return V;

def	windDrag (Vadj, Winddif):
    drag = Vadj*Winddif
    return drag;

def reset():
    global x
    x = 0.0
    global y
    y = 1.0
    global vTot
    vTot = 49
    global vx
    vx = v*cos(radians(35))
    global vy
    vy = v*sin(radians(35))
    return;

#Euler method for velocity without drag#
for i in range(1000):
    x += vx*dt
    y += vy*dt
    vx = getNewV(vx, vy, 0, 0)
    vy = getNewV(vx, vy, 0, 1)
    xlist.append(x) #adds data to a list#
    ylist.append(y) #adds data to a list#
    if y <= 0:
        break
        
reset()

for i in range(1000):
    x += vx*dt
    y += vy*dt
    vx = getNewV(vx, vy, -4.4704, 0)
    vy = getNewV(vx, vy, -4.4704, 1)
    xheadlist.append(x) #adds data to a list#
    yheadlist.append(y) #adds data to a list#
    if y <= 0:
        break

reset()        
        
for i in range(1000):
    x += vx*dt
    y += vy*dt
    vx = getNewV(vx, vy, 4.4704, 0)
    vy = getNewV(vx, vy, 4.4704, 1)
    xtaillist.append(x) #adds data to a list#
    ytaillist.append(y) #adds data to a list#
    if y <= 0:
        break

# %%
#Creates a plot with all three sets of data#
# %matplotlib
plt.margins(0)
plt.plot(xlist, ylist, 'k')
plt.plot(xheadlist, yheadlist, 'r--')
plt.plot(xtaillist, ytaillist, 'g--')
plt.yticks(ticks = (0,10,20,30))
plt.xticks(ticks = (0,50,100,150))
plt.title("Trajectory of a batted baseball")
plt.xlabel("x (m)")
plt.ylabel("y (m)")
plt.legend(["no wind", "headwind", "tailwind"])
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg
